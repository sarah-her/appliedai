# %% [markdown]
# # Assignment 9 – The Blackjack Learner: Understanding Monte Carlo Reinforcement Learning
# ### Fundamentals of Reinforcement Learning and Monte Carlo Estimation
#
# **Topics Covered:** Reinforcement Learning Foundations, Markov Decision Processes (MDPs), Monte Carlo Prediction and Policy Evaluation
# **Environment:** A simulated Blackjack game designed to model agent–environment interaction and sequential decision-making under uncertainty.
#
# ## Theoretical Concept:
#
# Reinforcement Learning (RL) is a computational framework in which an agent learns to make decisions through interaction with an environment.
# At each time step \( t \), the agent observes a state \( S_t \), chooses an action \( A_t \), receives a reward \( R_{t+1} \), and transitions to a new state \( S_{t+1} \).
# The goal is to learn a policy \( \pi(a|s) \) that maximizes the expected return
#
# \[
# G_t = R_{t+1} + \gamma R_{t+2} + \gamma^2 R_{t+3} + \dots
# \]
#
# where \( \gamma \) is the discount factor controlling the importance of future rewards.
#
# ### Markov Decision Process (MDP):
# An MDP defines this interaction through the tuple \( (S, A, P, R, \gamma) \), representing states, actions, transition probabilities, rewards, and the discount factor.
# The Markov property assumes that the next state depends only on the current state and action, enabling tractable modeling of sequential decisions.
#
# ### Monte Carlo Prediction:
# Monte Carlo methods estimate value functions by averaging returns from complete episodes of experience.
# For a state \( s \), the value estimate \( V(s) \) is updated as
#
# \[
# V(s) \leftarrow V(s) + \alpha [G_t - V(s)]
# \]
#
# where \( G_t \) is the total reward (return) observed after visiting state \( s \).
# These methods do not require a model of the environment and converge with sufficient sampling.
#
# ### Assignment Context:
# In this assignment, a simplified Blackjack environment is used to demonstrate how an agent learns optimal play through experience. By repeatedly playing simulated games, the agent estimates the expected reward of different game states using Monte Carlo averaging. You will visualize learned value patterns, interpret how decisions improve through experience, and discuss the properties of RL algorithms.

# %% [markdown]
# # Step 1 – Import libraries

# %%
import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2 – Define simple helper functions

# %%
def draw_card():
    """Draws a random card (1–10)."""
    card = random.randint(1, 13)     ### FILL IN BLANK: max card number
    return min(card, 10)             ### FILL IN BLANK: face cards adjustment


def hand_value(hand):
    """Calculates total hand value considering usable ace."""
    value = sum(hand)                ### FILL IN BLANK: compute sum
    if 1 in hand and value + 10 <= 21:   ### FILL IN BLANK: ace check
        return value + 10
    return value                        ### FILL IN BLANK: return total


def is_bust(hand):
    """Returns True if hand value > 21."""
    return hand_value(hand) > 21            ### FILL IN BLANK: helper call


# Quick test
sample_hand = [draw_card(), draw_card()]         ### FILL IN BLANK: draw two cards
print("Sample Hand:", sample_hand)
print("Hand Value:", hand_value(sample_hand))
print("Is it a bust?", is_bust(sample_hand))
# Out:
# Sample Hand: [1, 10]
# Hand Value: 21
# Is it a bust? False

# %% [markdown]
# **Interpretation Question:**
# What is the purpose of the helper functions defined above?
#
# * I think the purpose of the help functions is to break down the game logic into actionable steps. One step for evaluating a hand's value and one for checking if the hand's value has gone over 21.

# %% [markdown]
# # Step 3 – Simulate one Blackjack episode

# %%
def play_blackjack_debug():
    player = [draw_card(), draw_card()]     ### FILL IN BLANK: draw two cards
    dealer = [draw_card(), draw_card()]     ### FILL IN BLANK: draw two cards
    episode = []

    print("\n--- New Game ---")
    print(f"Initial Player Hand: {player} (Value = {hand_value(player)})")   ### FILL IN BLANK
    print(f"Dealer Shows: {dealer[0]}")

    # Define initial state/action
    state = (hand_value(player), dealer[0],
             1 in player and hand_value(player) + 10 <= 21)   ### FILL IN BLANKS: compute state
    action = "stick"

    # Player’s turn
    while hand_value(player) < 20:      ### FILL IN BLANK: stopping condition
        state = (hand_value(player), dealer[0],
                 1 in player and hand_value(player) + 10 <= 21)

        # Simple policy
        if hand_value(player) < 17:     ### FILL IN BLANK: condition for hit
            action = "hit"
        else:
            action = "stick"

        print(f"\nPlayer decides to {action.upper()} at value {hand_value(player)}")

        if action == "hit":
            player.append(draw_card())  ### FILL IN BLANK: draw a card
            print(f"New Player Hand: {player} (Value = {hand_value(player)})")
            if is_bust(player):       ### FILL IN BLANK: check for bust
                print("Player busts! Hand value:", hand_value(player))
                episode.append((state, action, -1))
                print("Reward: -1 (Loss)")
                return episode
        else:
            print("Player sticks at:", hand_value(player))
            break

    # Dealer’s turn
    print("\nDealer's turn begins.")
    while hand_value(dealer) < 17:      ### FILL IN BLANK
        dealer.append(draw_card())     ### FILL IN BLANK
        print(f"Dealer draws. Dealer Hand: {dealer} (Value = {hand_value(dealer)})")

    player_score = hand_value(player)
    dealer_score = hand_value(dealer)
    reward = np.sign(player_score - dealer_score)

    print("\nFinal Player Hand:", player, "Value:", player_score)
    print("Final Dealer Hand:", dealer, "Value:", dealer_score)

    if reward == 1:
        print("Result: Player Wins (+1)")
    elif reward == 0:
        print("Result: Draw (0)")
    else:
        print("Result: Dealer Wins (-1)")

    episode.append((state, action, reward))
    return episode


for i in range(3):
    result = play_blackjack_debug()
    print("Episode data:", result)
# Out:
# --- New Game ---
# Initial Player Hand: [10, 7] (Value = 17)
# Dealer Shows: 6
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 7] Value: 17
# Final Dealer Hand: [6, 1] Value: 17
# Result: Draw (0)
# Episode data: [((17, 6, False), 'stick', 0)]
#
# --- New Game ---
# Initial Player Hand: [4, 3] (Value = 7)
# Dealer Shows: 10
#
# Player decides to HIT at value 7
# New Player Hand: [4, 3, 2] (Value = 9)
#
# Player decides to HIT at value 9
# New Player Hand: [4, 3, 2, 5] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [4, 3, 2, 5, 7] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 4] (Value = 16)
# Dealer draws. Dealer Hand: [10, 2, 4, 10] (Value = 26)
#
# Final Player Hand: [4, 3, 2, 5, 7] Value: 21
# Final Dealer Hand: [10, 2, 4, 10] Value: 26
# Result: Dealer Wins (-1)
# Episode data: [((14, 10, False), 'hit', -1)]
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 8
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 5] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 6, 9] (Value = 23)
#
# Final Player Hand: [6, 10, 5] Value: 21
# Final Dealer Hand: [8, 6, 9] Value: 23
# Result: Dealer Wins (-1)
# Episode data: [((16, 8, False), 'hit', -1)]

# %% [markdown]
# **Interpretation Question:**
# Looking at the game outputs above, what do these episode traces show about how the agent interacts with the environment, and how can this information be used for learning?
#
# * The episode traces above show sequential decisions made at each state. The agent is able to learn how its actions affect long-term outcomes through this closed feedback loop.

# %% [markdown]
# # Step 4 – Monte Carlo Value Estimation

# %%
def mc_value_estimation(num_games=5000):     ### FILL IN BLANK: choose total episodes
    V = defaultdict(float)   ### FILL IN BLANK: store average returns
    N = defaultdict(int)   ### FILL IN BLANK: count visits

    print("Starting Monte Carlo estimation...")

    for game in range(num_games):
        episode = play_blackjack_debug()    ### FILL IN BLANK: simulate a game
        G = 0
        seen = set()

        # Loop backward through episode
        for state, action, reward in reversed(episode):   ### FILL IN BLANK: iterate in reverse
            G += reward
            if state not in seen:
                seen.add(state)
                N[state] += 1
                V[state] += (G - V[state]) / N[state]

        # Minimal progress output
        if game == num_games // 2:   ### FILL IN BLANK: midpoint check
            print("Halfway through... learning in progress.")

    print("Monte Carlo estimation completed.")
    return V


# Run estimation
V = mc_value_estimation(2000)   ### FILL IN BLANK: specify number of games
print("Number of unique states learned:", len(V))
# Out:
# Starting Monte Carlo estimation...
#
# --- New Game ---
# Initial Player Hand: [7, 8] (Value = 15)
# Dealer Shows: 10
#
# Player decides to HIT at value 15
# New Player Hand: [7, 8, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 8, 3] Value: 18
# Final Dealer Hand: [10, 8] Value: 18
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [8, 4] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [8, 4, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 3
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 2] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 10] (Value = 23)
#
# Final Player Hand: [5, 10, 2] Value: 17
# Final Dealer Hand: [3, 10, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 5] (Value = 11)
# Dealer Shows: 8
#
# Player decides to HIT at value 11
# New Player Hand: [6, 5, 10] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 3, 5] (Value = 16)
# Dealer draws. Dealer Hand: [8, 3, 5, 10] (Value = 26)
#
# Final Player Hand: [6, 5, 10] Value: 21
# Final Dealer Hand: [8, 3, 5, 10] Value: 26
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 4] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [8, 4, 5] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 4, 5] Value: 17
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 4] (Value = 6)
# Dealer Shows: 10
#
# Player decides to HIT at value 6
# New Player Hand: [2, 4, 3] (Value = 9)
#
# Player decides to HIT at value 9
# New Player Hand: [2, 4, 3, 8] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [2, 4, 3, 8] Value: 17
# Final Dealer Hand: [10, 7] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 2
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 10, 7] (Value = 19)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [2, 10, 7] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 3
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 1, 4] (Value = 18)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [3, 1, 4] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 8
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 1] (Value = 20)
# Dealer Shows: 2
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 7, 10] (Value = 19)
#
# Final Player Hand: [9, 1] Value: 20
# Final Dealer Hand: [2, 7, 10] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [2, 7] (Value = 9)
# Dealer Shows: 3
#
# Player decides to HIT at value 9
# New Player Hand: [2, 7, 7] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [2, 7, 7, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 5] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [9, 5, 9] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 3] (Value = 12)
# Dealer Shows: 9
#
# Player decides to HIT at value 12
# New Player Hand: [9, 3, 1] (Value = 13)
#
# Player decides to HIT at value 13
# New Player Hand: [9, 3, 1, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 10
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 3] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 3, 1] (Value = 14)
# Dealer draws. Dealer Hand: [10, 3, 1, 7] (Value = 21)
#
# Final Player Hand: [6, 10, 3] Value: 19
# Final Dealer Hand: [10, 3, 1, 7] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [4, 1] (Value = 15)
# Dealer Shows: 2
#
# Player decides to HIT at value 15
# New Player Hand: [4, 1, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 10, 7] (Value = 19)
#
# Final Player Hand: [4, 1, 3] Value: 18
# Final Dealer Hand: [2, 10, 7] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 2] (Value = 10)
# Dealer Shows: 10
#
# Player decides to HIT at value 10
# New Player Hand: [8, 2, 10] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 2] (Value = 14)
# Dealer draws. Dealer Hand: [10, 2, 2, 1] (Value = 15)
# Dealer draws. Dealer Hand: [10, 2, 2, 1, 10] (Value = 25)
#
# Final Player Hand: [8, 2, 10] Value: 20
# Final Dealer Hand: [10, 2, 2, 1, 10] Value: 25
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 6
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 6, 7] (Value = 19)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [6, 6, 7] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [3, 2] (Value = 5)
# Dealer Shows: 8
#
# Player decides to HIT at value 5
# New Player Hand: [3, 2, 8] (Value = 13)
#
# Player decides to HIT at value 13
# New Player Hand: [3, 2, 8, 2] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 2, 8, 2, 7] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 1] (Value = 14)
# Dealer Shows: 4
#
# Player decides to HIT at value 14
# New Player Hand: [3, 1, 2] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [3, 1, 2, 10] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [3, 1, 2, 10, 8] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [2, 10] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [2, 10, 3] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [2, 10, 3, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 6] (Value = 12)
# Dealer Shows: 7
#
# Player decides to HIT at value 12
# New Player Hand: [6, 6, 9] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 6, 10] (Value = 23)
#
# Final Player Hand: [6, 6, 9] Value: 21
# Final Dealer Hand: [7, 6, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 3] (Value = 9)
# Dealer Shows: 9
#
# Player decides to HIT at value 9
# New Player Hand: [6, 3, 2] (Value = 11)
#
# Player decides to HIT at value 11
# New Player Hand: [6, 3, 2, 6] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 6, 3] (Value = 18)
#
# Final Player Hand: [6, 3, 2, 6] Value: 17
# Final Dealer Hand: [9, 6, 3] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 9] (Value = 19)
# Dealer Shows: 3
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 1, 5] (Value = 19)
#
# Final Player Hand: [10, 9] Value: 19
# Final Dealer Hand: [3, 1, 5] Value: 19
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [7, 7] (Value = 14)
# Dealer Shows: 9
#
# Player decides to HIT at value 14
# New Player Hand: [7, 7, 8] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 9
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 2] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 10, 2] Value: 18
# Final Dealer Hand: [9, 10] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 3] (Value = 14)
# Dealer Shows: 9
#
# Player decides to HIT at value 14
# New Player Hand: [1, 3, 5] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
#
# Final Player Hand: [1, 3, 5] Value: 19
# Final Dealer Hand: [9, 10] Value: 19
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 9] (Value = 19)
# Dealer Shows: 7
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 9] Value: 19
# Final Dealer Hand: [7, 1] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [7, 4] (Value = 11)
# Dealer Shows: 2
#
# Player decides to HIT at value 11
# New Player Hand: [7, 4, 4] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [7, 4, 4, 1] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [7, 4, 4, 1, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 10
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [10, 10] Value: 20
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [3, 7] (Value = 10)
# Dealer Shows: 3
#
# Player decides to HIT at value 10
# New Player Hand: [3, 7, 7] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 5, 8] (Value = 16)
# Dealer draws. Dealer Hand: [3, 5, 8, 3] (Value = 19)
#
# Final Player Hand: [3, 7, 7] Value: 17
# Final Dealer Hand: [3, 5, 8, 3] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 5] (Value = 11)
# Dealer Shows: 6
#
# Player decides to HIT at value 11
# New Player Hand: [6, 5, 10] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 5, 10] Value: 21
# Final Dealer Hand: [6, 1] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [9, 2] (Value = 11)
# Dealer Shows: 10
#
# Player decides to HIT at value 11
# New Player Hand: [9, 2, 2] (Value = 13)
#
# Player decides to HIT at value 13
# New Player Hand: [9, 2, 2, 8] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [9, 2, 2, 8] Value: 21
# Final Dealer Hand: [10, 10] Value: 20
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [2, 9] (Value = 11)
# Dealer Shows: 5
#
# Player decides to HIT at value 11
# New Player Hand: [2, 9, 10] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 4, 10] (Value = 19)
#
# Final Player Hand: [2, 9, 10] Value: 21
# Final Dealer Hand: [5, 4, 10] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [1, 1] (Value = 12)
# Dealer Shows: 2
#
# Player decides to HIT at value 12
# New Player Hand: [1, 1, 4] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [1, 1, 4, 5] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 10, 6] (Value = 18)
#
# Final Player Hand: [1, 1, 4, 5] Value: 21
# Final Dealer Hand: [2, 10, 6] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 3
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 1, 7] (Value = 21)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [3, 1, 7] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 10] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [3, 10, 3] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [3, 10, 3, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 2] (Value = 10)
# Dealer Shows: 6
#
# Player decides to HIT at value 10
# New Player Hand: [8, 2, 9] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 7, 5] (Value = 18)
#
# Final Player Hand: [8, 2, 9] Value: 19
# Final Dealer Hand: [6, 7, 5] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [3, 2] (Value = 5)
# Dealer Shows: 9
#
# Player decides to HIT at value 5
# New Player Hand: [3, 2, 9] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [3, 2, 9, 1] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 2, 9, 1, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 6
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 8] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 5] (Value = 9)
# Dealer Shows: 1
#
# Player decides to HIT at value 9
# New Player Hand: [4, 5, 1] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [4, 5, 1] Value: 20
# Final Dealer Hand: [1, 6] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 1
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [1, 4, 3] (Value = 18)
#
# Final Player Hand: [5, 10, 3] Value: 18
# Final Dealer Hand: [1, 4, 3] Value: 18
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [7, 3] (Value = 10)
# Dealer Shows: 7
#
# Player decides to HIT at value 10
# New Player Hand: [7, 3, 10] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 7, 10] (Value = 24)
#
# Final Player Hand: [7, 3, 10] Value: 20
# Final Dealer Hand: [7, 7, 10] Value: 24
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 6] (Value = 17)
# Dealer Shows: 5
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 9, 2] (Value = 16)
# Dealer draws. Dealer Hand: [5, 9, 2, 3] (Value = 19)
#
# Final Player Hand: [1, 6] Value: 17
# Final Dealer Hand: [5, 9, 2, 3] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 10] (Value = 17)
# Dealer Shows: 10
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 10] Value: 17
# Final Dealer Hand: [10, 1] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 10] (Value = 21)
# Dealer Shows: 10
#
# Dealer's turn begins.
#
# Final Player Hand: [1, 10] Value: 21
# Final Dealer Hand: [10, 9] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [7, 9] (Value = 16)
# Dealer Shows: 2
#
# Player decides to HIT at value 16
# New Player Hand: [7, 9, 7] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [7, 3] (Value = 10)
# Dealer Shows: 9
#
# Player decides to HIT at value 10
# New Player Hand: [7, 3, 2] (Value = 12)
#
# Player decides to HIT at value 12
# New Player Hand: [7, 3, 2, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 2] (Value = 5)
# Dealer Shows: 3
#
# Player decides to HIT at value 5
# New Player Hand: [3, 2, 10] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 2, 10, 5] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 10] (Value = 23)
#
# Final Player Hand: [3, 2, 10, 5] Value: 20
# Final Dealer Hand: [3, 10, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 10
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [10, 1] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 4
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 4] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 9, 3] (Value = 16)
# Dealer draws. Dealer Hand: [4, 9, 3, 10] (Value = 26)
#
# Final Player Hand: [6, 10, 4] Value: 20
# Final Dealer Hand: [4, 9, 3, 10] Value: 26
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 6
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 8, 8] (Value = 22)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [6, 8, 8] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [9, 10] (Value = 19)
# Dealer Shows: 2
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 1, 1] (Value = 14)
# Dealer draws. Dealer Hand: [2, 1, 1, 7] (Value = 21)
#
# Final Player Hand: [9, 10] Value: 19
# Final Dealer Hand: [2, 1, 1, 7] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 8] (Value = 10)
# Dealer Shows: 6
#
# Player decides to HIT at value 10
# New Player Hand: [2, 8, 4] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [2, 8, 4, 9] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 6
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 7, 10] (Value = 23)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [6, 7, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [5, 5] (Value = 10)
# Dealer Shows: 10
#
# Player decides to HIT at value 10
# New Player Hand: [5, 5, 5] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [5, 5, 5, 9] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 10
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 9] (Value = 21)
#
# Final Player Hand: [10, 5, 3] Value: 18
# Final Dealer Hand: [10, 2, 9] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 10
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [10, 10] Value: 20
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [3, 10] (Value = 13)
# Dealer Shows: 1
#
# Player decides to HIT at value 13
# New Player Hand: [3, 10, 1] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [3, 10, 1, 7] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [3, 10, 1, 7] Value: 21
# Final Dealer Hand: [1, 10] Value: 21
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 7] (Value = 17)
# Dealer Shows: 4
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 7, 1] (Value = 12)
# Dealer draws. Dealer Hand: [4, 7, 1, 6] (Value = 18)
#
# Final Player Hand: [10, 7] Value: 17
# Final Dealer Hand: [4, 7, 1, 6] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 6
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 6] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 3] (Value = 11)
# Dealer Shows: 10
#
# Player decides to HIT at value 11
# New Player Hand: [8, 3, 9] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 3, 9] Value: 20
# Final Dealer Hand: [10, 10] Value: 20
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [1, 6] (Value = 17)
# Dealer Shows: 8
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 2, 2] (Value = 12)
# Dealer draws. Dealer Hand: [8, 2, 2, 5] (Value = 17)
#
# Final Player Hand: [1, 6] Value: 17
# Final Dealer Hand: [8, 2, 2, 5] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [5, 9] (Value = 14)
# Dealer Shows: 2
#
# Player decides to HIT at value 14
# New Player Hand: [5, 9, 1] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [5, 9, 1, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 9] (Value = 18)
# Dealer Shows: 7
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 3, 10] (Value = 20)
#
# Final Player Hand: [9, 9] Value: 18
# Final Dealer Hand: [7, 3, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [9, 10] (Value = 19)
# Dealer Shows: 10
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
#
# Final Player Hand: [9, 10] Value: 19
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 3] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [10, 3, 3] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [10, 3, 3, 6] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 10] (Value = 13)
# Dealer Shows: 5
#
# Player decides to HIT at value 13
# New Player Hand: [3, 10, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 3
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 7] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 4
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 5] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 8, 8] (Value = 20)
#
# Final Player Hand: [4, 10, 5] Value: 19
# Final Dealer Hand: [4, 8, 8] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 2] (Value = 8)
# Dealer Shows: 5
#
# Player decides to HIT at value 8
# New Player Hand: [6, 2, 10] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 3, 2] (Value = 10)
# Dealer draws. Dealer Hand: [5, 3, 2, 1] (Value = 21)
#
# Final Player Hand: [6, 2, 10] Value: 18
# Final Dealer Hand: [5, 3, 2, 1] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 3] (Value = 10)
# Dealer Shows: 7
#
# Player decides to HIT at value 10
# New Player Hand: [7, 3, 5] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [7, 3, 5, 2] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 3, 4] (Value = 14)
# Dealer draws. Dealer Hand: [7, 3, 4, 10] (Value = 24)
#
# Final Player Hand: [7, 3, 5, 2] Value: 17
# Final Dealer Hand: [7, 3, 4, 10] Value: 24
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 6] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [7, 6, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [2, 4] (Value = 6)
# Dealer Shows: 10
#
# Player decides to HIT at value 6
# New Player Hand: [2, 4, 10] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [2, 4, 10, 8] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 7] (Value = 15)
# Dealer Shows: 4
#
# Player decides to HIT at value 15
# New Player Hand: [8, 7, 5] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 10, 10] (Value = 24)
#
# Final Player Hand: [8, 7, 5] Value: 20
# Final Dealer Hand: [4, 10, 10] Value: 24
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 1] (Value = 19)
# Dealer Shows: 9
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 7, 4] (Value = 20)
#
# Final Player Hand: [8, 1] Value: 19
# Final Dealer Hand: [9, 7, 4] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 6] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [7, 6, 8] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 6, 8] Value: 21
# Final Dealer Hand: [10, 7] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [1, 4] (Value = 15)
# Dealer Shows: 9
#
# Player decides to HIT at value 15
# New Player Hand: [1, 4, 1] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [1, 4, 1, 10] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [1, 4, 1, 10, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [7, 7] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [7, 7, 3] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 6, 10] (Value = 26)
#
# Final Player Hand: [7, 7, 3] Value: 17
# Final Dealer Hand: [10, 6, 10] Value: 26
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 4] (Value = 15)
# Dealer Shows: 8
#
# Player decides to HIT at value 15
# New Player Hand: [1, 4, 2] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [1, 4, 2] Value: 17
# Final Dealer Hand: [8, 10] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 10] (Value = 17)
# Dealer Shows: 10
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 10] Value: 17
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 8] (Value = 18)
# Dealer Shows: 7
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 4, 6] (Value = 17)
#
# Final Player Hand: [10, 8] Value: 18
# Final Dealer Hand: [7, 4, 6] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [6, 5] (Value = 11)
# Dealer Shows: 9
#
# Player decides to HIT at value 11
# New Player Hand: [6, 5, 10] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 5, 10] Value: 21
# Final Dealer Hand: [9, 10] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [9, 10] (Value = 19)
# Dealer Shows: 5
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 10, 10] (Value = 25)
#
# Final Player Hand: [9, 10] Value: 19
# Final Dealer Hand: [5, 10, 10] Value: 25
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 4] (Value = 15)
# Dealer Shows: 7
#
# Player decides to HIT at value 15
# New Player Hand: [1, 4, 6] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 2, 7] (Value = 16)
# Dealer draws. Dealer Hand: [7, 2, 7, 1] (Value = 17)
#
# Final Player Hand: [1, 4, 6] Value: 21
# Final Dealer Hand: [7, 2, 7, 1] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [8, 4] (Value = 12)
# Dealer Shows: 1
#
# Player decides to HIT at value 12
# New Player Hand: [8, 4, 4] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [8, 4, 4, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [1, 8] (Value = 19)
# Dealer Shows: 3
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 7, 7] (Value = 17)
#
# Final Player Hand: [1, 8] Value: 19
# Final Dealer Hand: [3, 7, 7] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [9, 10] (Value = 19)
# Dealer Shows: 2
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 10, 7] (Value = 19)
#
# Final Player Hand: [9, 10] Value: 19
# Final Dealer Hand: [2, 10, 7] Value: 19
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 3] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [4, 10, 3] Value: 17
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 6
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 7] (Value = 10)
# Dealer Shows: 8
#
# Player decides to HIT at value 10
# New Player Hand: [3, 7, 7] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 5, 4] (Value = 17)
#
# Final Player Hand: [3, 7, 7] Value: 17
# Final Dealer Hand: [8, 5, 4] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 6] (Value = 16)
# Dealer Shows: 9
#
# Player decides to HIT at value 16
# New Player Hand: [10, 6, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 9
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 2] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [10, 2, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 10
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [10, 8] Value: 18
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 1
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 4] (Value = 7)
# Dealer Shows: 3
#
# Player decides to HIT at value 7
# New Player Hand: [3, 4, 6] (Value = 13)
#
# Player decides to HIT at value 13
# New Player Hand: [3, 4, 6, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 9] (Value = 13)
# Dealer Shows: 6
#
# Player decides to HIT at value 13
# New Player Hand: [4, 9, 7] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 10, 2] (Value = 18)
#
# Final Player Hand: [4, 9, 7] Value: 20
# Final Dealer Hand: [6, 10, 2] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [9, 1] (Value = 20)
# Dealer Shows: 8
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 4, 10] (Value = 22)
#
# Final Player Hand: [9, 1] Value: 20
# Final Dealer Hand: [8, 4, 10] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 9] (Value = 19)
# Dealer Shows: 8
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 5, 2] (Value = 15)
# Dealer draws. Dealer Hand: [8, 5, 2, 2] (Value = 17)
#
# Final Player Hand: [10, 9] Value: 19
# Final Dealer Hand: [8, 5, 2, 2] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [5, 5] (Value = 10)
# Dealer Shows: 10
#
# Player decides to HIT at value 10
# New Player Hand: [5, 5, 7] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 3, 10] (Value = 23)
#
# Final Player Hand: [5, 5, 7] Value: 17
# Final Dealer Hand: [10, 3, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 6] (Value = 13)
# Dealer Shows: 3
#
# Player decides to HIT at value 13
# New Player Hand: [7, 6, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 5] (Value = 9)
# Dealer Shows: 4
#
# Player decides to HIT at value 9
# New Player Hand: [4, 5, 10] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 7, 3] (Value = 14)
# Dealer draws. Dealer Hand: [4, 7, 3, 1] (Value = 15)
# Dealer draws. Dealer Hand: [4, 7, 3, 1, 10] (Value = 25)
#
# Final Player Hand: [4, 5, 10] Value: 19
# Final Dealer Hand: [4, 7, 3, 1, 10] Value: 25
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 10] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [3, 10, 6] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 6] (Value = 18)
#
# Final Player Hand: [3, 10, 6] Value: 19
# Final Dealer Hand: [10, 2, 6] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [5, 2] (Value = 7)
# Dealer Shows: 1
#
# Player decides to HIT at value 7
# New Player Hand: [5, 2, 7] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [5, 2, 7, 2] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [5, 2, 7, 2, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [7, 4] (Value = 11)
# Dealer Shows: 1
#
# Player decides to HIT at value 11
# New Player Hand: [7, 4, 10] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 4, 10] Value: 21
# Final Dealer Hand: [1, 10] Value: 21
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 1
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [1, 3, 8] (Value = 12)
# Dealer draws. Dealer Hand: [1, 3, 8, 8] (Value = 20)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [1, 3, 8, 8] Value: 20
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 8] (Value = 18)
# Dealer Shows: 10
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 8] Value: 18
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 8
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 3, 10] (Value = 21)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [8, 3, 10] Value: 21
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 10
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 8] (Value = 10)
# Dealer Shows: 9
#
# Player decides to HIT at value 10
# New Player Hand: [2, 8, 10] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [2, 8, 10] Value: 20
# Final Dealer Hand: [9, 9] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 9
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 3] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 7, 3] (Value = 19)
#
# Final Player Hand: [6, 10, 3] Value: 19
# Final Dealer Hand: [9, 7, 3] Value: 19
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [4, 4] (Value = 8)
# Dealer Shows: 8
#
# Player decides to HIT at value 8
# New Player Hand: [4, 4, 10] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 7, 4] (Value = 19)
#
# Final Player Hand: [4, 4, 10] Value: 18
# Final Dealer Hand: [8, 7, 4] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 1
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [1, 6] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 1
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 6] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [1, 4, 10] (Value = 15)
# Dealer draws. Dealer Hand: [1, 4, 10, 3] (Value = 18)
#
# Final Player Hand: [10, 4, 6] Value: 20
# Final Dealer Hand: [1, 4, 10, 3] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [6, 9] (Value = 15)
# Dealer Shows: 7
#
# Player decides to HIT at value 15
# New Player Hand: [6, 9, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 4] (Value = 8)
# Dealer Shows: 4
#
# Player decides to HIT at value 8
# New Player Hand: [4, 4, 3] (Value = 11)
#
# Player decides to HIT at value 11
# New Player Hand: [4, 4, 3, 4] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [4, 4, 3, 4, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 3
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 8] (Value = 21)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [3, 10, 8] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [9, 7] (Value = 16)
# Dealer Shows: 8
#
# Player decides to HIT at value 16
# New Player Hand: [9, 7, 1] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 3, 1] (Value = 12)
# Dealer draws. Dealer Hand: [8, 3, 1, 5] (Value = 17)
#
# Final Player Hand: [9, 7, 1] Value: 17
# Final Dealer Hand: [8, 3, 1, 5] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [2, 7] (Value = 9)
# Dealer Shows: 8
#
# Player decides to HIT at value 9
# New Player Hand: [2, 7, 7] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [2, 7, 7, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 3
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 5] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 10] (Value = 23)
#
# Final Player Hand: [6, 10, 5] Value: 21
# Final Dealer Hand: [3, 10, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 6] (Value = 9)
# Dealer Shows: 10
#
# Player decides to HIT at value 9
# New Player Hand: [3, 6, 1] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 4, 3] (Value = 17)
#
# Final Player Hand: [3, 6, 1] Value: 20
# Final Dealer Hand: [10, 4, 3] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 3
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 7] (Value = 17)
# Dealer Shows: 8
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 7] Value: 17
# Final Dealer Hand: [8, 10] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 1] (Value = 17)
# Dealer Shows: 10
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 1] Value: 17
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [5, 1] (Value = 16)
# Dealer Shows: 10
#
# Player decides to HIT at value 16
# New Player Hand: [5, 1, 6] (Value = 12)
#
# Player decides to HIT at value 12
# New Player Hand: [5, 1, 6, 2] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [5, 1, 6, 2, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [2, 5] (Value = 7)
# Dealer Shows: 7
#
# Player decides to HIT at value 7
# New Player Hand: [2, 5, 1] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 6, 10] (Value = 23)
#
# Final Player Hand: [2, 5, 1] Value: 18
# Final Dealer Hand: [7, 6, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 7] (Value = 10)
# Dealer Shows: 9
#
# Player decides to HIT at value 10
# New Player Hand: [3, 7, 10] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [3, 7, 10] Value: 20
# Final Dealer Hand: [9, 10] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [4, 4] (Value = 8)
# Dealer Shows: 5
#
# Player decides to HIT at value 8
# New Player Hand: [4, 4, 2] (Value = 10)
#
# Player decides to HIT at value 10
# New Player Hand: [4, 4, 2, 6] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [4, 4, 2, 6, 4] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 10, 3] (Value = 18)
#
# Final Player Hand: [4, 4, 2, 6, 4] Value: 20
# Final Dealer Hand: [5, 10, 3] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [6, 6] (Value = 12)
# Dealer Shows: 8
#
# Player decides to HIT at value 12
# New Player Hand: [6, 6, 5] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 6, 5] Value: 17
# Final Dealer Hand: [8, 10] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 7] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [6, 7, 3] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [6, 7, 3, 9] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 2] (Value = 6)
# Dealer Shows: 10
#
# Player decides to HIT at value 6
# New Player Hand: [4, 2, 9] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [4, 2, 9, 6] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [4, 2, 9, 6] Value: 21
# Final Dealer Hand: [10, 10] Value: 20
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [7, 6] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [7, 6, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 6
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 9] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 6] (Value = 15)
# Dealer Shows: 10
#
# Player decides to HIT at value 15
# New Player Hand: [9, 6, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 3, 10] (Value = 23)
#
# Final Player Hand: [9, 6, 3] Value: 18
# Final Dealer Hand: [10, 3, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 4
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 9] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 7
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [7, 3, 5] (Value = 15)
# Dealer draws. Dealer Hand: [7, 3, 5, 5] (Value = 20)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [7, 3, 5, 5] Value: 20
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 10
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 1] (Value = 17)
# Dealer Shows: 2
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 8, 9] (Value = 19)
#
# Final Player Hand: [6, 1] Value: 17
# Final Dealer Hand: [2, 8, 9] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 9] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [3, 9, 5] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 10] (Value = 22)
#
# Final Player Hand: [3, 9, 5] Value: 17
# Final Dealer Hand: [10, 2, 10] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 3] (Value = 9)
# Dealer Shows: 9
#
# Player decides to HIT at value 9
# New Player Hand: [6, 3, 3] (Value = 12)
#
# Player decides to HIT at value 12
# New Player Hand: [6, 3, 3, 7] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 2, 10] (Value = 21)
#
# Final Player Hand: [6, 3, 3, 7] Value: 19
# Final Dealer Hand: [9, 2, 10] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 6
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 6, 10] (Value = 22)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [6, 6, 10] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 2] (Value = 12)
# Dealer Shows: 3
#
# Player decides to HIT at value 12
# New Player Hand: [10, 2, 3] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [10, 2, 3, 2] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 4, 10] (Value = 17)
#
# Final Player Hand: [10, 2, 3, 2] Value: 17
# Final Dealer Hand: [3, 4, 10] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [3, 3] (Value = 6)
# Dealer Shows: 8
#
# Player decides to HIT at value 6
# New Player Hand: [3, 3, 6] (Value = 12)
#
# Player decides to HIT at value 12
# New Player Hand: [3, 3, 6, 9] (Value = 21)
#
# Dealer's turn begins.
#
# Final Player Hand: [3, 3, 6, 9] Value: 21
# Final Dealer Hand: [8, 10] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [7, 5] (Value = 12)
# Dealer Shows: 4
#
# Player decides to HIT at value 12
# New Player Hand: [7, 5, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [2, 8] (Value = 10)
# Dealer Shows: 10
#
# Player decides to HIT at value 10
# New Player Hand: [2, 8, 10] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [2, 8, 10] Value: 20
# Final Dealer Hand: [10, 7] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 1
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [1, 1, 7] (Value = 19)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [1, 1, 7] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [5, 9] (Value = 14)
# Dealer Shows: 6
#
# Player decides to HIT at value 14
# New Player Hand: [5, 9, 2] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [5, 9, 2, 4] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 10, 3] (Value = 19)
#
# Final Player Hand: [5, 9, 2, 4] Value: 20
# Final Dealer Hand: [6, 10, 3] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 6] (Value = 16)
# Dealer Shows: 7
#
# Player decides to HIT at value 16
# New Player Hand: [10, 6, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 9] (Value = 13)
# Dealer Shows: 1
#
# Player decides to HIT at value 13
# New Player Hand: [4, 9, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 7
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [7, 7] (Value = 14)
# Dealer Shows: 1
#
# Player decides to HIT at value 14
# New Player Hand: [7, 7, 1] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [7, 7, 1, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 7, 1, 3] Value: 18
# Final Dealer Hand: [1, 10] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [4, 9] (Value = 13)
# Dealer Shows: 3
#
# Player decides to HIT at value 13
# New Player Hand: [4, 9, 8] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 9, 10] (Value = 22)
#
# Final Player Hand: [4, 9, 8] Value: 21
# Final Dealer Hand: [3, 9, 10] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 4] (Value = 6)
# Dealer Shows: 7
#
# Player decides to HIT at value 6
# New Player Hand: [2, 4, 10] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [2, 4, 10, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [3, 9] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [3, 9, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 9] (Value = 17)
# Dealer Shows: 10
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 9] Value: 17
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 10
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [10, 7] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# ...
# Final Dealer Hand: [4, 10, 8] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 2
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 5, 8] (Value = 15)
# Dealer draws. Dealer Hand: [2, 5, 8, 10] (Value = 25)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [2, 5, 8, 10] Value: 25
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 7] (Value = 17)
# Dealer Shows: 8
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 7] Value: 17
# Final Dealer Hand: [8, 10] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 3] (Value = 6)
# Dealer Shows: 10
#
# Player decides to HIT at value 6
# New Player Hand: [3, 3, 2] (Value = 8)
#
# Player decides to HIT at value 8
# New Player Hand: [3, 3, 2, 7] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 3, 2, 7, 1] (Value = 16)
#
# Player decides to HIT at value 16
# New Player Hand: [3, 3, 2, 7, 1, 10] (Value = 26)
# Player busts! Hand value: 26
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 9] (Value = 17)
# Dealer Shows: 10
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 9] Value: 17
# Final Dealer Hand: [10, 9] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [5, 8] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [5, 8, 7] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 3, 8] (Value = 21)
#
# Final Player Hand: [5, 8, 7] Value: 20
# Final Dealer Hand: [10, 3, 8] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 10
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 2] (Value = 10)
# Dealer Shows: 8
#
# Player decides to HIT at value 10
# New Player Hand: [8, 2, 9] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [8, 3, 3] (Value = 14)
# Dealer draws. Dealer Hand: [8, 3, 3, 10] (Value = 24)
#
# Final Player Hand: [8, 2, 9] Value: 19
# Final Dealer Hand: [8, 3, 3, 10] Value: 24
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 9] (Value = 12)
# Dealer Shows: 5
#
# Player decides to HIT at value 12
# New Player Hand: [3, 9, 7] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 2, 9] (Value = 16)
# Dealer draws. Dealer Hand: [5, 2, 9, 6] (Value = 22)
#
# Final Player Hand: [3, 9, 7] Value: 19
# Final Dealer Hand: [5, 2, 9, 6] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 4
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 10, 9] (Value = 23)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [4, 10, 9] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 6] (Value = 16)
# Dealer Shows: 2
#
# Player decides to HIT at value 16
# New Player Hand: [10, 6, 7] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 4
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 4, 9] (Value = 17)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [4, 4, 9] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 4] (Value = 14)
# Dealer Shows: 5
#
# Player decides to HIT at value 14
# New Player Hand: [10, 4, 7] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 7, 9] (Value = 21)
#
# Final Player Hand: [10, 4, 7] Value: 21
# Final Dealer Hand: [5, 7, 9] Value: 21
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 2
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 2, 10] (Value = 14)
# Dealer draws. Dealer Hand: [2, 2, 10, 2] (Value = 16)
# Dealer draws. Dealer Hand: [2, 2, 10, 2, 1] (Value = 17)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [2, 2, 10, 2, 1] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [9, 6] (Value = 15)
# Dealer Shows: 1
#
# Player decides to HIT at value 15
# New Player Hand: [9, 6, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 10
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [10, 7] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [4, 1] (Value = 15)
# Dealer Shows: 7
#
# Player decides to HIT at value 15
# New Player Hand: [4, 1, 10] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [4, 1, 10, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 3] (Value = 13)
# Dealer Shows: 1
#
# Player decides to HIT at value 13
# New Player Hand: [10, 3, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [6, 5] (Value = 11)
# Dealer Shows: 6
#
# Player decides to HIT at value 11
# New Player Hand: [6, 5, 3] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [6, 5, 3, 3] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [6, 5, 3, 3] Value: 17
# Final Dealer Hand: [6, 1] Value: 17
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [3, 9] (Value = 12)
# Dealer Shows: 10
#
# Player decides to HIT at value 12
# New Player Hand: [3, 9, 8] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [3, 9, 8] Value: 20
# Final Dealer Hand: [10, 8] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 7
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [7, 10] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [5, 5] (Value = 10)
# Dealer Shows: 8
#
# Player decides to HIT at value 10
# New Player Hand: [5, 5, 10] (Value = 20)
#
# Dealer's turn begins.
#
# Final Player Hand: [5, 5, 10] Value: 20
# Final Dealer Hand: [8, 10] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [1, 4] (Value = 15)
# Dealer Shows: 4
#
# Player decides to HIT at value 15
# New Player Hand: [1, 4, 9] (Value = 14)
#
# Player decides to HIT at value 14
# New Player Hand: [1, 4, 9, 5] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 9, 1] (Value = 14)
# Dealer draws. Dealer Hand: [4, 9, 1, 7] (Value = 21)
#
# Final Player Hand: [1, 4, 9, 5] Value: 19
# Final Dealer Hand: [4, 9, 1, 7] Value: 21
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [1, 10] (Value = 21)
# Dealer Shows: 6
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [6, 9, 1] (Value = 16)
# Dealer draws. Dealer Hand: [6, 9, 1, 3] (Value = 19)
#
# Final Player Hand: [1, 10] Value: 21
# Final Dealer Hand: [6, 9, 1, 3] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [1, 4] (Value = 15)
# Dealer Shows: 3
#
# Player decides to HIT at value 15
# New Player Hand: [1, 4, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 10] (Value = 23)
#
# Final Player Hand: [1, 4, 3] Value: 18
# Final Dealer Hand: [3, 10, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 10] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 9] (Value = 13)
# Dealer Shows: 10
#
# Player decides to HIT at value 13
# New Player Hand: [4, 9, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [5, 10] (Value = 15)
# Dealer Shows: 2
#
# Player decides to HIT at value 15
# New Player Hand: [5, 10, 6] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 3, 6] (Value = 11)
# Dealer draws. Dealer Hand: [2, 3, 6, 10] (Value = 21)
#
# Final Player Hand: [5, 10, 6] Value: 21
# Final Dealer Hand: [2, 3, 6, 10] Value: 21
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [4, 10] (Value = 14)
# Dealer Shows: 7
#
# Player decides to HIT at value 14
# New Player Hand: [4, 10, 9] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [5, 9] (Value = 14)
# Dealer Shows: 3
#
# Player decides to HIT at value 14
# New Player Hand: [5, 9, 3] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 10, 10] (Value = 23)
#
# Final Player Hand: [5, 9, 3] Value: 17
# Final Dealer Hand: [3, 10, 10] Value: 23
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 10] (Value = 12)
# Dealer Shows: 4
#
# Player decides to HIT at value 12
# New Player Hand: [2, 10, 3] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [2, 10, 3, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [8, 10] (Value = 18)
# Dealer Shows: 9
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 3, 10] (Value = 22)
#
# Final Player Hand: [8, 10] Value: 18
# Final Dealer Hand: [9, 3, 10] Value: 22
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [2, 10] (Value = 12)
# Dealer Shows: 4
#
# Player decides to HIT at value 12
# New Player Hand: [2, 10, 10] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [4, 4] (Value = 8)
# Dealer Shows: 10
#
# Player decides to HIT at value 8
# New Player Hand: [4, 4, 10] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
#
# Final Player Hand: [4, 4, 10] Value: 18
# Final Dealer Hand: [10, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [9, 3] (Value = 12)
# Dealer Shows: 9
#
# Player decides to HIT at value 12
# New Player Hand: [9, 3, 5] (Value = 17)
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 3, 3] (Value = 15)
# Dealer draws. Dealer Hand: [9, 3, 3, 9] (Value = 24)
#
# Final Player Hand: [9, 3, 5] Value: 17
# Final Dealer Hand: [9, 3, 3, 9] Value: 24
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 5
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 10, 1] (Value = 16)
# Dealer draws. Dealer Hand: [5, 10, 1, 10] (Value = 26)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [5, 10, 1, 10] Value: 26
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 8] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [6, 8, 8] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 7
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 7] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 1] (Value = 21)
# Dealer Shows: 10
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 4, 3] (Value = 17)
#
# Final Player Hand: [10, 1] Value: 21
# Final Dealer Hand: [10, 4, 3] Value: 17
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 9
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [9, 6, 10] (Value = 25)
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [9, 6, 10] Value: 25
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [3, 1] (Value = 14)
# Dealer Shows: 10
#
# Player decides to HIT at value 14
# New Player Hand: [3, 1, 1] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 1, 1, 10] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [3, 1, 1, 10, 7] (Value = 22)
# Player busts! Hand value: 22
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 10] (Value = 20)
# Dealer Shows: 8
#
# Dealer's turn begins.
#
# Final Player Hand: [10, 10] Value: 20
# Final Dealer Hand: [8, 10] Value: 18
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [2, 1] (Value = 13)
# Dealer Shows: 2
#
# Player decides to HIT at value 13
# New Player Hand: [2, 1, 7] (Value = 20)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 7, 10] (Value = 19)
#
# Final Player Hand: [2, 1, 7] Value: 20
# Final Dealer Hand: [2, 7, 10] Value: 19
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [7, 6] (Value = 13)
# Dealer Shows: 5
#
# Player decides to HIT at value 13
# New Player Hand: [7, 6, 8] (Value = 21)
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [5, 4, 1] (Value = 20)
#
# Final Player Hand: [7, 6, 8] Value: 21
# Final Dealer Hand: [5, 4, 1] Value: 20
# Result: Player Wins (+1)
#
# --- New Game ---
# Initial Player Hand: [10, 8] (Value = 18)
# Dealer Shows: 10
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [10, 2, 7] (Value = 19)
#
# Final Player Hand: [10, 8] Value: 18
# Final Dealer Hand: [10, 2, 7] Value: 19
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [6, 10] (Value = 16)
# Dealer Shows: 9
#
# Player decides to HIT at value 16
# New Player Hand: [6, 10, 7] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [10, 9] (Value = 19)
# Dealer Shows: 2
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [2, 4, 7] (Value = 13)
# Dealer draws. Dealer Hand: [2, 4, 7, 6] (Value = 19)
#
# Final Player Hand: [10, 9] Value: 19
# Final Dealer Hand: [2, 4, 7, 6] Value: 19
# Result: Draw (0)
#
# --- New Game ---
# Initial Player Hand: [2, 6] (Value = 8)
# Dealer Shows: 3
#
# Player decides to HIT at value 8
# New Player Hand: [2, 6, 7] (Value = 15)
#
# Player decides to HIT at value 15
# New Player Hand: [2, 6, 7, 10] (Value = 25)
# Player busts! Hand value: 25
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 6] (Value = 15)
# Dealer Shows: 4
#
# Player decides to HIT at value 15
# New Player Hand: [9, 6, 3] (Value = 18)
#
# Player decides to STICK at value 18
# Player sticks at: 18
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [4, 2, 4] (Value = 10)
# Dealer draws. Dealer Hand: [4, 2, 4, 10] (Value = 20)
#
# Final Player Hand: [9, 6, 3] Value: 18
# Final Dealer Hand: [4, 2, 4, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [5, 8] (Value = 13)
# Dealer Shows: 7
#
# Player decides to HIT at value 13
# New Player Hand: [5, 8, 10] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [7, 9] (Value = 16)
# Dealer Shows: 3
#
# Player decides to HIT at value 16
# New Player Hand: [7, 9, 3] (Value = 19)
#
# Player decides to STICK at value 19
# Player sticks at: 19
#
# Dealer's turn begins.
# Dealer draws. Dealer Hand: [3, 3, 4] (Value = 10)
# Dealer draws. Dealer Hand: [3, 3, 4, 10] (Value = 20)
#
# Final Player Hand: [7, 9, 3] Value: 19
# Final Dealer Hand: [3, 3, 4, 10] Value: 20
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [7, 10] (Value = 17)
# Dealer Shows: 9
#
# Player decides to STICK at value 17
# Player sticks at: 17
#
# Dealer's turn begins.
#
# Final Player Hand: [7, 10] Value: 17
# Final Dealer Hand: [9, 9] Value: 18
# Result: Dealer Wins (-1)
#
# --- New Game ---
# Initial Player Hand: [10, 5] (Value = 15)
# Dealer Shows: 5
#
# Player decides to HIT at value 15
# New Player Hand: [10, 5, 9] (Value = 24)
# Player busts! Hand value: 24
# Reward: -1 (Loss)
#
# --- New Game ---
# Initial Player Hand: [9, 6] (Value = 15)
# Dealer Shows: 4
#
# Player decides to HIT at value 15
# New Player Hand: [9, 6, 8] (Value = 23)
# Player busts! Hand value: 23
# Reward: -1 (Loss)
# Monte Carlo estimation completed.
# Number of unique states learned: 123

# %% [markdown]
# **Interpretation Question:**
# Why does Monte Carlo estimation use averaging across many episodes?
#
# * Monte Carlo estimation uses averaging across many episodes in order to estimate the true expected return that takes into account all individual episosdes.

# %%
sample_states = list(V.items())[:10]    ### FILL IN BLANK: access learned states, choose sample size
print("\n--- Sample of Learned State Values ---")

for s, val in sample_states:                          ### FILL IN BLANK: iterate through sampled states
    print(f"State: {s},  Value: {val:.3f}")
# Out:
# --- Sample of Learned State Values ---
# State: (18, 10, False),  Value: -0.596
# State: (12, 10, False),  Value: -0.615
# State: (17, 3, False),  Value: -0.786
# State: (11, 8, False),  Value: -0.200
# State: (17, 10, False),  Value: -0.843
# State: (21, 2, False),  Value: 0.000
# State: (21, 3, False),  Value: 0.167
# State: (14, 8, False),  Value: -0.750
# State: (20, 2, False),  Value: 0.222
# State: (16, 3, False),  Value: -0.800

# %% [markdown]
# **Interpretation Question:**
# What does a positive or negative value indicate for a given state?
#
# * A positive value means that the player is more likely to win than lose and a negative value means that the player is more likey to lose than win.

# %% [markdown]
# # Step 5 – Visualize Value Function (with and without usable ace)

# %%
# Step 6 – Visualize learned state values

usable_ace = np.zeros((10, 10))         ### FILL IN BLANK: set grid dimensions
no_usable_ace = np.zeros((10, 10))

for (player, dealer, ace) in V.keys():          ### FILL IN BLANK: iterate through learned states
    if 12 <= player <= 21 and 1 <= dealer <= 10:
        if ace:
            usable_ace[player-12][dealer-1] = V.get((player, dealer, ace), 0)
        else:
            no_usable_ace[player-12][dealer-1] = V.get((player, dealer, ace), 0)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))   ### FILL IN BLANK: figure size

# With usable ace
im1 = axes[0].imshow(usable_ace, origin='lower', cmap='coolwarm', vmin=-1, vmax=1)   ### FILL IN BLANK: color map
axes[0].set_title('Value with Usable Ace')
axes[0].set_xlabel('Dealer Showing')
axes[0].set_ylabel('Player Sum')
plt.colorbar(im1, ax=axes[0])

# Without usable ace
im2 = axes[1].imshow(no_usable_ace, origin='lower', cmap='coolwarm', vmin=-1, vmax=1)
axes[1].set_title('Value without Usable Ace')
axes[1].set_xlabel('Dealer Showing')
axes[1].set_ylabel('Player Sum')
plt.colorbar(im2, ax=axes[1])

plt.show()

# %% [markdown]
# **Interpretation Question:**
# How does having a usable ace influence the expected return?
#
# * Having a usable ace influences the expected return by affecting the state's risk of bust.

# %% [markdown]
# # **Reflection and Discussion**
#
# **Question 1:**
# During training, you observed the progress messages as games were completed. What does the increasing number of games tell you about the stability or convergence of the estimated state values? How would you know if the value function has converged?
#
# * Since the estimated state value is the sample mean of its returns, increasing the number of games will increase the stability due to lower variance.
#
# **Question 2:**
# Examine the value heatmaps for usable and non-usable aces. What insights can you draw about the role of flexibility in decision-making, and how does the presence of a usable ace change optimal behavior?
#
# **Question 3:**
# Review the printed sample of learned state values. Some states have slightly negative values even after many episodes. What factors could cause persistent underestimation or overestimation in Monte Carlo value estimation?
#
# **Question 4:**
# Consider the random action policy used during game simulation. If the agent instead followed a more informed policy (e.g., hit below 17, stick otherwise), how might that affect both the learned values and the learning efficiency?
#
# **Question 5:**
# Reflect on the overall learning pattern seen in the heatmaps and sample outputs. What does this tell you about the relationship between experiential learning and decision quality in reinforcement learning systems?
